# %% [markdown]
# In this notebook, we will look into how to derive elegant formulas to update the weights in the neural network

# %% [markdown]
# ### Backpropagation formula w.r.t weights

# %% [markdown]
# Okay, so in this scenario we will try to calculate the derivative of the Loss w.r.t to the weights of a particular layer. We will consider 3 batches of inputs. Let's see how can we derive a formula.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, let's try to write the entire Loss with respect to w11

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Okay, so once we know this, let's try to write the entire loss with respect to w11

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Therefore, the elegant formula to remember is this -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Backpropagation formula w.r.t the inputs
# This is important to compute because this will be passed on to the previous layer as dl_dz. And that's how the gradient will keep moving backwards!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is what the calculation shows us, we get a feel that it depends on the weights matrix and the dl_dz matrix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We want to calculate the following matrix. This will serve as the dl_dz matrix for the previous layer.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, if you notice, dl_dz x Weights transpose will provide me with the desired result.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Similarly, we can compute the gradients w.r.t to all other parameters and here is the summary.

# %% [markdown]
# ![image.png](attachment:image.png)
