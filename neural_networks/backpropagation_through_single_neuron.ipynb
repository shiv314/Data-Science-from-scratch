# %% [markdown]
# ## Single Neuron Setup
#
# Today, we will discuss the backpropagation concepts in detail through a single neuron. This forms the backbone of all the neural network architectures we see today.
#
# Let's consider a single neuron with 3 inputs and a ReLU activation layer is applied to get the final prediction. Let's assume that the true value of y is zero, and the error that we are considering is the Mean Squared Error (MSE).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Chain Rule
#
# Now, let's try to find the change in the error with change in the input variables. We will try to find the error with random initial values because that's how the weights are assigned in a neural network in the start. Let's build a computation graph. This will help us to visualise the steps that are being taken to reach to the output.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Let's try to find the partial derivative of the error with respect to w1.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Similarly, we find the partial derivative of the error with respect to all our parameters which are w1, w2, w3 and b.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Parameters Update
# Now, we update the parameters by taking a small step(called as learning rate) in the opposite direction of the gradient.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, Let's check if the error was reduced from 36
# If you calculate the final error, it will come to 35.42! That's awesome :)
# Now, you can do a lot of iterations till you meet your stopping condition.
#
# This lies at the heart of training a neural network. Hope you got a good intuition and understanding of this process!
# Thanks!
